# %%
# %run py_import.py

# %%
properties = ['输出','KDA','发育','团战','生存']
values = [40,91,44,90,95,40]
theta = np.linspace(0, 2 * np.pi, 6)
plt.polar(theta,values)
plt.fill(theta,values)
plt.show()

# %% [markdown]
# **使用`plt.subplot`绘制的子图**

# %%
axes = plt.subplot(111,projection = 'polar')
axes.plot(theta,values)
axes.fill(theta,values)
plt.show()

# %% [markdown]
# **使用`plt.subplots`绘制的子图**

# %%
figure,axes = plt.subplots(1,1,subplot_kw = {'projection':'polar'})
axes.plot(theta,values)
axes.fill(theta,values)

# %% [markdown]
# **使用`fig.add_subplot`绘制的子图**

# %%
fig = plt.figure(figsize = (5,5))
axes = fig.add_subplot(111,polar = True)
axes.plot(theta,values)
plt.show()

# %% [markdown]
# ### 笔记：
# 1. 用来表示多个维度的值的强弱关系
# 2. 绘制雷达图：
#     * 因为雷达图绘制的时候，不会自动的封闭，所有要在数据的最后添加一个起始点的坐标
#     * plt.polar绘制
#     * plt.subplot(111,projection = 'polar')
#     * figure,axes = plt.subplot(1,1,subplot_kw = {"projection":"polar"})
#     * axes = fig.add_subplot(111,polar = True)
