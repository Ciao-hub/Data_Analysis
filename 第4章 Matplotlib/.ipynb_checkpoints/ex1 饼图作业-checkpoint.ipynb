# %%
# %run py_import.py

# %%
browsers = {
    "Chrome": 0.6098,
    "Internet Explorer": 0.1218,
    "FireFox": 0.1147,
    "Edge": 0.0415,
    "Safari": 0.0372,
    "其他浏览器": 0.075
}
patches,texts, autotexts = plt.pie(browsers.values(),normalize = True,labels = browsers.keys(),
                                   autopct = "%0.2f%%",textprops = {'fontproperties':font},
                                   shadow = True, explode = (0,0.05,0,0,0,0))
for index,autotext in enumerate(autotexts):
    autotext.set_color('w')
    if index == 3 or index ==4:
        autotext.set_size('10')
plt.show()
