# %%
# %run py_import.py
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data[0]['title']
# Out:
# 'BUG: Wrong time data when using GMT+/-xy time zones'

# %%
issues = pd.DataFrame(data, columns = ['number','title','labels','state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    43669  BUG: Wrong time data when using GMT+/-xy time ...
# 1    43668  BUG: DataFrame.convert_dtypes doesn't preserve...
# 2    43667                                       43659-bugfix
# 3    43666  ENH: RangeIndex.sort_values now avoids materia...
# 4    43665               DEPR: rolling/expanding/ewm.validate
# 5    43664    TYP: Redundant imports to define the public API
# 6    43663                         ENH: Add Inner Fill Option
# 7    43662  WIP: ENH: `Styler.bar` accepts matplotlib colo...
# 8    43661                REF: simplify IndexEngine signature
# 9    43660                         CI: adding cython coverage
# 10   43659                 BUG: rename fails when using level
# 11   43658              DEPR: Fix deprecation warnings in ASV
# 12   43657  BUG: add css conversion for new `Styler.apply_...
# 13   43656      DOC: expand allowed vals for `multicol_align`
# 14   43654                                  PERF: sparse take
# 15   43653  REF: ExtensionIndex.searchsorted -> IndexOpsMi...
# 16   43652                          CI: codecov for pyx files
# 17   43651                         REF: remove JoinUnit.shape
# 18   43650                  CI/BUG: pyarrow read_csv deadlock
# 19   43649  BUG: styler multiindex hiding indexes and colu...
# 20   43648  BUG: latex css conversion does not work on new...
# 21   43647                                            Gh43540
# 22   43644  BUG: styler hide_index hide_columns misaligns ...
# 23   43643                                 CI: azure timeouts
# 24   43642                            CLN: Python Parser code
# 25   43640  backport 43638: BUG: styler to_latex doesnt re...
# 26   43638  wip: BUG: styler hide index fails for latex tr...
# 27   43637  BUG: `styler.to_latex` does hide rows after `h...
# 28   43635  WIP: DEPR: remove methods deprecated in 1.3.0 ...
# 29   43634                    PERF: groupby with string dtype
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 2                                                  []  open
# 3                                                  []  open
# 4   [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 5   [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 6   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 7                                                  []  open
# 8                                                  []  open
# 9                                                  []  open
# 10  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 11                                                 []  open
# 12                                                 []  open
# 13  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 14  [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 15                                                 []  open
# 16  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 17                                                 []  open
# 18  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 19                                                 []  open
# 20  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 21  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 22  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 23  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 24                                                 []  open
# 25                                                 []  open
# 26                                                 []  open
# 27  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 28                                                 []  open
# 29  [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNj...  open
